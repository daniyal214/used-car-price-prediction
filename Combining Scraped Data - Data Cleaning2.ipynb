# %%
import pandas as pd
import numpy as np
import glob

# %%
pd.options.display.max_rows = False

# %%
# df = pd.concat([pd.read_csv(f, low_memory=False).reset_index(drop=True) for f in glob.glob('Finals' + "/*."+'csv')],
#           ignore_index=True)

# %%
df_1 = pd.read_csv('./Finals/Till30k.csv', low_memory=False)
df_2 = pd.read_csv('./Finals/30k-40k.csv', low_memory=False)
df_3 = pd.read_csv('./Finals/40k-50k.csv', low_memory=False)
df_4 = pd.read_csv('./Finals/50kto70k.csv', low_memory=False)
df_5 = pd.read_csv('./Finals/70k-80k.csv', low_memory=False)
df_6 = pd.read_csv('./Finals/80k-90k.csv', low_memory=False)
df_7 = pd.read_csv('./Finals/90k-100k.csv', low_memory=False)

# %%
df_1.drop(df_1.index[30001:], inplace=True)

# %%
df_2.drop(df_2.index[40001:], inplace=True)
df_2.drop(df_2.index[:30001], inplace=True)

# %%
df_3.drop(df_3.index[50001:], inplace=True)
df_3.drop(df_3.index[:40001], inplace=True)

# %%
df_4.drop(df_4.index[70001:], inplace=True)
df_4.drop(df_4.index[:50001], inplace=True)

# %%
df_5.drop(df_5.index[80001:], inplace=True)
df_5.drop(df_5.index[:70001], inplace=True)

# %%
df_6.drop(df_6.index[90001:], inplace=True)
df_6.drop(df_6.index[:80001], inplace=True)

# %%
df_7.drop(df_7.index[100001:], inplace=True)
df_7.drop(df_7.index[:90001], inplace=True)

# %%
df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7])

# %%
df
# Out:
#           Make     Model  Model_Year Fuel_Type Transmission  \
# 0          FAW        V2        2015    Petrol       Manual
# 1          FAW        V2        2017    Petrol       Manual
# 2          FAW      X-PV        2016    Petrol       Manual
# 3          FAW      X-PV        2013    Petrol       Manual
# 4          FAW        V2        2015    Petrol       Manual
# 5          FAW        V2        2018    Petrol       Manual
# 6          FAW      X-PV        2017    Petrol       Manual
# 7          FAW        V2        2017    Petrol       Manual
# 8          FAW        V2        2019    Petrol       Manual
# ...        ...       ...         ...       ...          ...
# 99992   Toyota  Fortuner        2013    Petrol    Automatic
# 99993   Toyota   Corolla        2018    Petrol       Manual
# 99994   Toyota   Corolla        2004    Diesel       Manual
# 99995   Toyota   Corolla        2011    Petrol       Manual
# 99996   Toyota   Corolla        2021    Petrol       Manual
# ...

# %%
#start 24584:28342

# %%
pd.options.display.max_rows = False

# %%
df[(df['Registration'] == 'Bahawalpur') & (df['Body_Type'] == 'Sedan') & (df['Color'] == 'White' ) ]
# Out:
#          Make    Model  Model_Year Fuel_Type Transmission  \
# 2611   Toyota  Corolla        2001    Petrol       Manual
# 4392   Toyota  Corolla        2018    Petrol       Manual
# 18302   Honda     City        2018    Petrol       Manual
# 20637   Honda     City        2021    Petrol       Manual
# 22696   Honda     City        2013    Petrol    Automatic
# 23621   Honda     City        2020    Petrol       Manual
# 24326   Honda     City        2002    Petrol       Manual
# 24643   Honda    Civic        2008    Petrol       Manual
# 28849   Honda     City        2006    Petrol       Manual
# 30897  Nissan    Sunny        1992    Petrol       Manual
# 30898  Nissan    Sunny        1992       CNG       Manual
# 30985  Nissan    Sunny        1986       CNG       Manual
# 31723  Nissan    Sunny        1990    Petrol       Manual
# 32349  Nissan    Sunny        1986    Petrol       Manual
# 45856  Suzuki    Liana        2006    Petrol       Manual
# ...

# %%
df = df.drop(df[24584:28343].index,)

# %%
# df['Fuel_Type'].value_counts()
# Out:
# Petrol      89984
# Hybrid       4406
# Diesel       3745
# CNG          1832
# Lpg            22
# Electric       12
# Name: Fuel_Type, dtype: int64

# %%
# df[df['Fuel_Type'] == 'Electric']
# Out:
#          Make   Model  Model_Year Fuel_Type Transmission  Engine_Capacity(cc)  \
# 1740       MG   ZS EV        2021  Electric    Automatic                    0
# 2088       MG   ZS EV        2021  Electric    Automatic                    0
# 12188    Audi  e-tron        2021  Electric    Automatic                 5000
# 12350    Audi  e-tron        2020  Electric    Automatic                    0
# 12380    Audi  e-tron        2021  Electric    Automatic                    0
# 12512    Audi  e-tron        2021  Electric    Automatic                 1800
# 15328   Honda   Civic        1984  Electric       Manual                    0
# 30684  Nissan    Note        2017  Electric    Automatic                    0
# 30708  Nissan    Note        2017  Electric    Automatic                    0
# 31955  Nissan    Note        2018  Electric    Automatic                    0
# 31981  Nissan    Note        2018  Electric    Automatic                    0
# ...

# %%
df['Capacity_KWh'] = df['Capacity']

# %%
df['Capacity_KWh'][0][-2:]
# Out:
# 'cc'

# %%
postfix = ['cc']

# %%
# [value[-2] if value[-2:] in postfix else value for value in df['Capacity_KWh']]

# %%
# np.where(df.Capacity_KWh.str[-2:] == 'cc', df.Capacity_KWh.str[-2:], df.Capacity_KWh)

# %%
df['Capacity_KWh'] = df['Capacity_KWh'].astype(object)

# %%
str(df['Capacity_KWh'][0][-2:])
# Out:
# 'cc'

# %%
def replace(x):
    if type(x) == float:
        x = str(x)
        if x[-2:] == 'cc':
            return(x.replace(x,'0'))
        else:
            return x
    else:
        if x[-2:] == 'cc':
            return(x.replace(x,'0'))
        else:
            return x

# %%
df['Capacity_KWh'] = df['Capacity_KWh'].map(replace)

# %%
df.isnull().sum()
# Out:
# Make                       0
# Model                      1
# Model_Year                 0
# Fuel_Type                  0
# Transmission               0
# Engine_Capacity(cc)        0
# Kms_Driven                 0
# Price                      0
# Url                        0
# Capacity                 117
# Registration             117
# Color                    117
# Assembly                 117
# Body_Type              10641
# Capacity_KWh               0
# dtype: int64

# %%
pd.options.display.max_seq_items = None
# lst_to_do = df[(df['Body_Type'].isnull()) & (df['Capacity'].notnull()) ].index

# %%
lst_to_do = df[df['Capacity'].isnull()].index

# %%
df.loc[19]['Url']
# Out:
# 'https://www.pakwheels.com/used-cars/faw-carrier-2018-for-sale-in-karachi-5340222'

# %%
df
# Out:
#           Make     Model  Model_Year Fuel_Type Transmission  \
# 0          FAW        V2        2015    Petrol       Manual
# 1          FAW        V2        2017    Petrol       Manual
# 2          FAW      X-PV        2016    Petrol       Manual
# 3          FAW      X-PV        2013    Petrol       Manual
# 4          FAW        V2        2015    Petrol       Manual
# 5          FAW        V2        2018    Petrol       Manual
# 6          FAW      X-PV        2017    Petrol       Manual
# 7          FAW        V2        2017    Petrol       Manual
# 8          FAW        V2        2019    Petrol       Manual
# ...        ...       ...         ...       ...          ...
# 99992   Toyota  Fortuner        2013    Petrol    Automatic
# 99993   Toyota   Corolla        2018    Petrol       Manual
# 99994   Toyota   Corolla        2004    Diesel       Manual
# 99995   Toyota   Corolla        2011    Petrol       Manual
# 99996   Toyota   Corolla        2021    Petrol       Manual
# ...

# %%
def replace_kwh(x):
    x = x.replace('kWh','').strip()
    return float(x)

# %%
df['Capacity_KWh'] = df['Capacity_KWh'].apply(replace_kwh)

# %%
df
# Out:
#           Make     Model  Model_Year Fuel_Type Transmission  \
# 0          FAW        V2        2015    Petrol       Manual
# 1          FAW        V2        2017    Petrol       Manual
# 2          FAW      X-PV        2016    Petrol       Manual
# 3          FAW      X-PV        2013    Petrol       Manual
# 4          FAW        V2        2015    Petrol       Manual
# 5          FAW        V2        2018    Petrol       Manual
# 6          FAW      X-PV        2017    Petrol       Manual
# 7          FAW        V2        2017    Petrol       Manual
# 8          FAW        V2        2019    Petrol       Manual
# ...        ...       ...         ...       ...          ...
# 99992   Toyota  Fortuner        2013    Petrol    Automatic
# 99993   Toyota   Corolla        2018    Petrol       Manual
# 99994   Toyota   Corolla        2004    Diesel       Manual
# 99995   Toyota   Corolla        2011    Petrol       Manual
# 99996   Toyota   Corolla        2021    Petrol       Manual
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96242 entries, 0 to 100000
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Make                 96242 non-null  object
#  1   Model                96241 non-null  object
#  2   Model_Year           96242 non-null  int64
#  3   Fuel_Type            96242 non-null  object
#  4   Transmission         96242 non-null  object
#  5   Engine_Capacity(cc)  96242 non-null  int64
#  6   Kms_Driven           96242 non-null  int64
#  7   Price                96242 non-null  int64
#  8   Url                  96242 non-null  object
#  9   Capacity             96125 non-null  object
#  10  Registration         96125 non-null  object
#  11  Color                96125 non-null  object
#  12  Assembly             96125 non-null  object
#  13  Body_Type            85601 non-null  object
#  14  Capacity_KWh         96125 non-null  float64
# ...

# %% [markdown]
# # List to Do

# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
len(list(df.loc[lst_to_do]['Url']))
# Out:
# 117

# %%
list(df.loc[lst_to_do]['Url'])
# Out:
# ['https://www.pakwheels.com/used-cars/toyota-prado-2009-for-sale-in-islamabad-5338066',
#  'https://www.pakwheels.com/used-cars/toyota-corolla-1998-for-sale-in-rawalpindi-5337506',
#  'https://www.pakwheels.com/used-cars/toyota-land-cruiser-1999-for-sale-in-nowshera-5336700',
#  'https://www.pakwheels.com/used-cars/toyota-corolla-2019-for-sale-in-islamabad-5336674',
#  'https://www.pakwheels.com/used-cars/toyota-corolla-1989-for-sale-in-islamabad-4766312',
#  'https://www.pakwheels.com/used-cars/honda-civic-2017-for-sale-in-karachi-5336923',
#  'https://www.pakwheels.com/used-cars/honda-accord-2003-for-sale-in-lahore-5335125',
#  'https://www.pakwheels.com/used-cars/honda-city-2021-for-sale-in-islamabad-5309790',
#  'https://www.pakwheels.com/used-cars/honda-civic-2020-for-sale-in-lahore-5332149',
#  'https://www.pakwheels.com/used-cars/honda-city-2021-for-sale-in-islamabad-5309790',
#  'https://www.pakwheels.com/used-cars/honda-city-2021-for-sale-in-lahore-5228134',
# ...

# %%
registration = []
color = []
assembly = []
capacity = []
body = []

# %%
for url in list(df.loc[lst_to_do]['Url']):
    response = requests.get(url)
    content = response.content
    read = BeautifulSoup(content, 'html.parser')
    details = read.find('ul', id = 'scroll_car_detail')
    
    if details != None:
        details = details.text.split('\n')
        items = [x for x in details if x]
        registration.append(items[1])
        color.append(items[3])
        assembly.append(items[5])
        capacity.append(items[7])
        body.append(items[9])
    else:
        registration.append('N/A')
        color.append('N/A')
        assembly.append('N/A')
        capacity.append('N/A')
        body.append('N/A')

# %%
len(registration)
# Out:
# 117

# %%
# # till 76
# reg_76 = registration
# c_76 = color
# as_76 = assembly
# cap_76 = capacity
# bd_76 = body

# %%
117-76
# Out:
# 41

# %%
len(df.loc[lst_to_do]['Url'])
# Out:
# 10705

# %%
fillna =  df[df['Capacity'].isnull()]

# %%
fillna = fillna.drop(['Capacity', 'Registration', 'Color', 'Assembly', 'Body_Type', 'Capacity_KWh'], axis=1)

# %%
fillna['Capacity'] = capacity
fillna['Registration'] = registration
fillna['Color'] = color
fillna['Assembly'] = assembly
fillna['Body_Type'] = body

# %%
fillna = fillna.drop(fillna[fillna['Capacity'] == 'N/A'].index)

# %%
fillna
# Out:
#          Make         Model  Model_Year Fuel_Type Transmission  \
# 73945  Toyota         Passo        2007    Petrol    Automatic
# 73946  Toyota       Corolla        1986    Petrol       Manual
# 73947  Toyota  Corolla Axio        2007    Petrol    Automatic
# 73948  Toyota       Corolla        2008    Petrol       Manual
# 73949  Toyota      Fortuner        2021    Diesel    Automatic
# 73950  Toyota         Prius        2008    Hybrid    Automatic
# 73951  Toyota       Corolla        2021    Petrol    Automatic
# 73952  Toyota         Hilux        2017    Diesel    Automatic
# 73953  Toyota       Corolla        2015    Petrol       Manual
# ...       ...           ...         ...       ...          ...
# 93960  Toyota         Yaris        2020    Petrol    Automatic
# 93961  Toyota       Corolla        2016    Petrol    Automatic
# 93962  Toyota         Prado        1996    Diesel    Automatic
# 93963  Toyota         Hilux        2013    Diesel    Automatic
# ...

# %%
df['Model'][df['Make'] == 'Mercedes Benz'].value_counts()
# Out:
# C Class              405
# E Class              304
# S Class               94
# CLA Class             13
# Other                 13
# SLK Class             10
# 200 D                 10
# CLK Class              8
# GLA Class              7
# A Class                6
# M Class                6
# D Series               6
#                     ...
# E Class Cabriolet      3
# Mb140                  3
# C Class Coupe          2
# Cl Class               2
# Vito                   2
# G Class                2
# Smart Forfour          2
# Se 220                 1
# Sl Class               1
# Ponton                 1
# 200 T                  1
# X                      1
# Name: Model, Length: 30, dtype: int64

# %%
fillna.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Model_Year             0
# Fuel_Type              0
# Transmission           0
# Engine_Capacity(cc)    0
# Kms_Driven             0
# Price                  0
# Url                    0
# Capacity               0
# Registration           0
# Color                  0
# Assembly               0
# Body_Type              0
# Capacity_KWh           0
# dtype: int64

# %%
df = df.drop(df[df['Capacity'].isnull()].index)

# %%
df['Model'] = df['Model'].fillna(value = '200 D')

# %%
df.shape
# Out:
# (99884, 15)

# %%
fillna.shape
# Out:
# (41, 14)

# %%
99884+41
# Out:
# 99925

# %%
df_new.isnull().sum()
# Out:
# Make                       0
# Model                      0
# Model_Year                 0
# Fuel_Type                  0
# Transmission               0
# Engine_Capacity(cc)        0
# Kms_Driven                 0
# Price                      0
# Url                        0
# Capacity                   0
# Registration               0
# Color                      0
# Assembly                   0
# Body_Type              10705
# Capacity_KWh              41
# dtype: int64

# %%
fillna['Capacity_KWh'] = fillna['Capacity']

# %%
def replace(x):
    if type(x) == float:
        x = str(x)
        if x[-2:] == 'cc':
            return(x.replace(x,'0'))
        else:
            return x
    else:
        if x[-2:] == 'cc':
            return(x.replace(x,'0'))
        else:
            return x

# %%
fillna['Capacity_KWh'] = fillna['Capacity_KWh'].map(replace)

# %%
def replace_kwh(x):
    x = x.replace('kWh','').strip()
    return float(x)

# %%
fillna['Capacity_KWh'] = fillna['Capacity_KWh'].apply(replace_kwh)

# %%
df_new = pd.concat([df,fillna])

# %%
df_new['Capacity'] = df_new['Capacity'].replace('cc', '', regex=True)
df_new['Capacity'] = df_new['Capacity'].replace('kWh', '', regex=True)

# %%
df_new['Capacity'] = df_new['Capacity'].astype(float)

# %%
index = df_new[(df_new['Capacity'] != df_new['Engine_Capacity(cc)']) & (df_new['Engine_Capacity(cc)'] != 0) & (df_new['Capacity_KWh'] == 0)].index

# %%
final = df_new.drop(index)

# %%
final.isnull().sum()
# Out:
# Make                       0
# Model                      1
# Model_Year                 0
# Fuel_Type                  0
# Transmission               0
# Engine_Capacity(cc)        0
# Kms_Driven                 0
# Price                      0
# Url                        0
# Capacity                   0
# Registration               0
# Color                      0
# Assembly                   0
# Body_Type              10514
# Capacity_KWh               0
# dtype: int64

# %%
final[final['Model'].isnull()]
# Out:
#                 Make Model  Model_Year Fuel_Type Transmission  \
# 64321  Mercedes Benz   NaN        1989    Diesel       Manual
#
#        Engine_Capacity(cc)  Kms_Driven    Price  \
# 64321                 3000      100000  1850000
#
#                                                      Url  Capacity  \
# 64321  https://www.pakwheels.com/used-cars/mercedes-b...    3000.0
#
#       Registration  Color  Assembly Body_Type  Capacity_KWh
# 64321    Islamabad  White  Imported       NaN           0.0

# %%
final['Model'] = final['Model'].fillna(value = '200 D')

# %%
final.isnull().sum()
# Out:
# Make                       0
# Model                      0
# Model_Year                 0
# Fuel_Type                  0
# Transmission               0
# Engine_Capacity(cc)        0
# Kms_Driven                 0
# Price                      0
# Url                        0
# Capacity                   0
# Registration               0
# Color                      0
# Assembly                   0
# Body_Type              10514
# Capacity_KWh               0
# dtype: int64

# %%
final.reset_index(drop=True, inplace=True)

# %%
final.to_csv('Final-PkWheel.csv', index=False)
